# %% [markdown]
# # Vorkurs Tag 3 - Aufgaben
#
# Author: Leon Gjinovci
#
# _Hinweis_: Der Schwierigkeitsgrad der Aufgaben wird durch die Anzahl an 😈-Smileys dargestellt. Alle Aufgaben sind zwischen 😈😈 und 😈😈😈😈

# %% [markdown]
# ## Aufgabe E.1
# Es wird eine Liste an monatlichen Ausgaben für ein Jahr vorgegeben:
# ```python
#
# monthly_spending = [2689.56, 2770.38, 2394.04, 2099.91, 3182.20, 3267.12, 1746.83, 2545.72, 3328.20, 3147.30, 2462.61, 3890.45]
#
# ```
# Man möchte seine durchschnittlichen Ausgaben innerhalb der Semester herausfinden (jeweils 6 Monate).
#
# _Tipp:_ Der Durchschnitt des ersten Semesters ist 2733.87, der des zweiten sit 2853.52

# %% [markdown]
# ## Aufgabe E.2
# Diese Liste an Spielern spielen Unterschiedliche Sportarten:
# ```python
# football_players = {"Eve", "Tom", "Richard", "Peter"}
# volleyball_players = {"Jack", "Hugh", "Peter", "Sam"}
# basketball_players = {"Eve", "Richard", "Jessica", "Sam", "Michael"}
# ```
# Wie können wir ein Set erhalten, das alle Spieler enthält, die nur Basketball spielen?

# %% [markdown]
# ## Aufgabe E.3
# Gegeben ist eine Liste an Wörtern:
# ```python
# word_list = ["apple", "airplane", "carrot", "elephant", "guitar", "moonlight"]
# ```
#
# Finde das längste und kürzeste Wort in der Liste. Gebe die Wörter in der Konsole aus.
# _Beispiel:_ Shortest Word: Apple

# %% [markdown]
# ## Aufgabe E.4
# Verändere die Aufgabe E.3 insoweit, dass der Nutzer eingene Eingaben in die word_list machen kann.

# %% [markdown]
# # Lösungen der Aufgaben
# ## E.1
# ```python
# monthly_spending = [2689.56, 2770.38, 2394.04, 2099.91, 3182.20, 3267.12, 1746.83, 2545.72, 3328.20, 3147.30, 2462.61, 3890.45]
#
# first_semester_total = 0
# second_semester_total = 0
#
# for index, expense in enumerate(monthly_spending):
#     if index < 6:
#         first_semester_total += expense
#     else:
#         second_semester_total += expense
#
# first_semester_avg = first_semester_total / 6
# second_semester_avg = second_semester_total / 6
#
# print("Average expenses for the first semester:", first_semester_avg)
# print("Average expenses for the second semester:", second_semester_avg)
# ```
# ## E.2
# ```python
# football_players = {"Eve", "Tom", "Richard", "Peter"}
# volleyball_players = {"Jack", "Hugh", "Peter", "Sam"}
# basketball_players = {"Eve", "Richard", "Jessica", "Sam", "Michael"}
#
# basketball_only_players = basketball_players - (football_players | volleyball_players)
#
# print("Basketball-only players:", basketball_only_players)
# ```
# ## E.3
# ```python
# word_list = ["apple", "airplane", "carrot", "elephant", "guitar", "moon"]
#
# longest_word = word_list[0]
# shortest_word = word_list[0]
#
# for word in word_list:
#     if len(word) > len(longest_word):
#         longest_word = word
#     elif len(word) < len(shortest_word):
#         shortest_word = word
#
# print("Longest word:", longest_word)
# print("Shortest word:", shortest_word)
# ```
# ## E.4
# Identische Logik zu E.3. Das Programm wird um eine Input-Aktion erweitert, die in die word_list schreibt.
