# %% [markdown]
# # Vorkurs Tag 1
#
# Author: Sebastian Krause

# %% [markdown]
# Übersicht heutiges Programm:
#
# 1. Variablen
# 2. Datentypen
# 3. Arithmetik
# 4. Konsolen Ein-/Ausgaben
# 5. Kommentare

# %% [markdown]
# ## 1. Variablen 📦
#
# - Variablen werden verwendet um Informationen zu speichern
# - In Python dynamische Typenbindung
# ### Benennung
#     - nur alphanumerische Zeichen verwenden: (A-Z), (a-z), (0-9)
#     - einziges erlaubtes Sonderzeichen: Unterstrich "_"
#     - erstes Zeichen keine Zahl
#     - Konvention: Variablennamen klein schreiben

# %% [markdown]
#     Beispiele Variableninitialisierung:

# %%
variablenname = ' Information   "ahsuidh"    '
variable = 'test'
zahl = 5
text = "Dies ist ein Text/String"
pi = 3.1415
wahrheitswert = True

# %% [markdown]
# *Merke:* Variablenname links, Wert rechts

# %%
print(variablenname)
# Out:
#  Information   "ahsuidh"

# %% [markdown]
# ## 2. Datentypen 🔢
#
# Es gibt unterschiedliche Arten von Variablen. In Python muss der Datentyp nicht explizit angegeben werden, da dieser anhand des Wertes, der in die Variable gespeichert wird, automatisch zugewiesen wird

# %% [markdown]
# |**Datentyp**|**Beispiel**|
# |:--- | :--- |
# |integer (Ganzzahl)|5, 0, -45|
# |float (Kommazahl) |2.5,  3.14,  -2.05|
# |bool (Wahrheitswert)| True, False|
# |string (Zeichenkette) | "Name", 'Eins', "Blau"|

# %% [markdown]
# ### Casten (Typ-Konvertierung)
#
# Das Ändern des Datentyps einer Variable nennt man "Casten" 🤓

# %%
zahl = 5

zahl = str(zahl)

# %%
type(zahl)
# Out:
# str

# %%
zahl
# Out:
# '5'

# %%
int(pi)
# Out:
# 3

# %% [markdown]
# *Anmerkung:* Bei Konvertierungen von float in int wird immer der Nachkommateil abgeschnitten --> es wird abgerundet

# %%
fast_vier = 3.9999
fast_vier = int(fast_vier)
fast_vier
# Out:
# 3

# %% [markdown]
# ### Konstanten

# %%
PI = 3.14159265
SPEED_OF_LIGHT = 299792458

# %% [markdown]
# ## 3. Arithmetik 🧮

# %% [markdown]
# mathematische Operatoren wie:  + , - , * , /
#
# können auf numerische Typen (int, float) angewendet werden

# %%
a = 5
b = 7
c = a + b
print(c)
# Out:
# 12

# %%
c = b / a
c
# Out:
# 1.4

# %% [markdown]
# Besondere Operatoren: \
# **Ganzzahldivision:**...  // \
# **Modulo:**....................% --> Restwert einer Division

# %%
c = b % a
c

c = b // a
c
# Out:
# 1

# %% [markdown]
# **Potenz**

# %%
(2**3) + 3
# Out:
# 11

# %% [markdown]
# **Zusammenfügen von Strings**

# %% [markdown]
# Auf String Variablen kann der "+"-Operator auch angewendet werden. Hierduch werden die beiden Zeichenketten zusammengefügt

# %%
 "Hello" + " " + "World" + " 4334"
# Out:
# 'Hello World 4334'

# %% [markdown]
# Der "\*"-Operator ist ebenso möglich

# %%
("Hello" + " " + "World" + " 4334 ") * 27
# Out:
# 'Hello World 4334 Hello World 4334 Hello World 4334 Hello World 4334 Hello World 4334 Hello World 4334 Hello World 4334 Hello World 4334 Hello World 4334 Hello World 4334 Hello World 4334 Hello World 4334 Hello World 4334 Hello World 4334 Hello World 4334 Hello World 4334 Hello World 4334 Hello World 4334 Hello World 4334 Hello World 4334 Hello World 4334 Hello World 4334 Hello World 4334 Hello World 4334 Hello World 4334 Hello World 4334 Hello World 4334 '

# %% [markdown]
# ## 4. Konsolen Ein-/Ausgaben 🖨️

# %% [markdown]
# Um mit dem Anwender eines Programms zu kommunizieren, können Ein- und Ausgaben auf das Konsolenfenster gemacht werden
# Ausgaben auf die Konsole: print()
# Eingaben von der Konsole: input()

# %%
a = 5
b = 10
a+b
print(f"Wort: {a} iadoiad {b}")
print("Test",a,"Test2")
# Out:
# Wort: 5 iadoiad 10
# Test 5 Test2

# %% [markdown]
# In Jupiter Notebook ist diese Funktion überflüssig, da jede Zelle eine eigene Ausgabe hat.

# %% [markdown]
# Optional kann bei einer Eingabe noch eine Nachricht dem Anwender mitgegeben werden.

# %%
eingabe = int(input("Gebe eine Zahl an:"))
# Out:
# Gebe eine Zahl an: 1243

# %%
print("Deine Zahl lautet:", eingabe)
# Out:
# Deine Zahl lautet: 1243

# %% [markdown]
# ## 5. Kommentare ✍️

# %% [markdown]
# Kommentare sind kurze Anmerkungen, die den Programmcode erklären. \
# Sie beginnen mit '#' und alles was in der Zeile dahinter steht wird vom Python Interpreter nicht interpretiert

# %%
# Dies ist ein Kommentar
# Kommentare beginnen mit einem '#'

# ahüd9ahdoih
# 

i = 5   # Variable i wird mit dem Wert 5 initialisiert

# %% [markdown]
# Kommentare werden vom Programmierer auch häufig dafür verwedet bestimmte Zeilen kurzfristig auszublenden

# %%
i = 3
i = 5
i
# Out:
# 5
